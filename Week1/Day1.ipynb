# %% [markdown]
# # 20240715
#
# ## Day1_ Data type: 정수, 실수, 문자열

# %%
# 변수 정의하기
x = 100
print(x)
# Out:
# 100

# %%
def root(a):
    new_Value = a ** 0.5
    return new_Value

root(2)
# Out:
# 1.4142135623730951

# %%
# 상수 변수명은 대문자로 하여 일반적인 변수와 구분하는 것이 관행
INCOME = 1000
TAX_RATE = 0.35
tax = INCOME * TAX_RATE

# %%
# 할당연산

x, y = 1, 2 ## x랑 y의 값을 각각 선언

x, y = y, x ## x,y의 값을 서로 교환

# %%
# 복합연산자 
## +=로 작성하며 대입과 다른 연산자를 합쳐놓은 것
num = 1
num += 2
num
# Out:
# 3

# %% [markdown]
# ## 연산 우선순위표
# ![image.png](attachment:image.png)

# %%
# 문자열의 결합
"Hello " + "World!"
# Out:
# 'Hello World!'

# %%
print("말 한마디로\n천냥빚을 갚지못한다.")
# Out:
# 말 한마디로
# 천냥빚을 갚지못한다.

# %%
# 문자열 인덱싱
s = "Hello World!"
print(s[5])
print(s[-1])
# Out:
#
# !

# %%
says = "Python's favorite food is perl."
print(says)
# Out:
# Python's favorite food is perl.

# %%
ftemp = 100

ctemp = (ftemp - 32.0) * 5.0 / 9.0
print("섭씨온도: ", ctemp)
# Out:
# 섭씨온도:  37.77777777777778

# %%
x = 1000
print("초깃값: ", x)
x += 2
print("x += 2 후: ", x)
x -= 2
print("x -= 2 후: ", x)
x *= 2
print("x *= 2 후: ", x)
x /= 2
print("x /= 2 후: ", int(x))
# Out:
# 초깃값:  1000
# x += 2 후:  1002
# x -= 2 후:  1000
# x *= 2 후:  2000
# x /= 2 후:  1000

# %%
# 괄호 사용하기 
num1 = 10
num2 = 20
print(num1 + num2 / 2)
print((num1 + num2) / 2)
# Out:
# 20.0
# 15.0

# %%
msg = "\"철수가 \"안녕\"이라고 말했습니다.\""
print(msg)
# Out:
# "철수가 "안녕"이라고 말했습니다."

# %%
a = '''서울시립대학교
경제학과
G202422001 김민재
'''
print(a)
# Out:
# 서울시립대학교
# 경제학과
# G202422001 김민재

# %%
"Hello " + "World!"
# Out:
# 'Hello World!'

# %%
# 문자열 반복
lines = "=" * 30
print(lines)

song = "뚜 루루 뚜루" * 5
print(song)
# Out:
# ...
# 뚜 루루 뚜루뚜 루루 뚜루뚜 루루 뚜루뚜 루루 뚜루뚜 루루 뚜루

# %%
# 문자열, 숫자열 구분하기
print(100 + 200)
print("100" + "200")
# Out:
# 300
# 100200

# %%
# 이스케이프 문자
print('"\\시립대\\"')
# Out:
# "\시립대\"

# %%
s = "서울시립대학교"
print("첫 번째 글짜는 %s" %(s[0]))
print("마지막 글짜는", s[-1])
# Out:
# 첫 번째 글짜는 서
# 마지막 글짜는 교

# %%
a = "Kim"
b = "Park"
acronym = a[0] + "와" + b[0]
print(acronym)
# Out:
# K와P

# %%
name  = input("이름을 입력해주세요: ")
print(name)
# Out:
# 이름을 입력해주세요: 김민재
# 김민재
